# %%
import pandas as pd

# %%
file_path="/Users/yanzhe.li/Documents/finance/sec_clean/data/first_html"

# %%
html_dir=os.listdir(file_path)

# %%
file=pd.read_html(file_path)

# %%
file
# Out:
# [   0                                                  1
#  0  ☒  ANNUAL REPORT PURSUANT TO SECTION 13 OR 15(d) ...,
#     0                                                  1
#  0  ☐  TRANSITION REPORT PURSUANT TO SECTION 13 OR 15...,
#                                                     0  \
#  0                  ART’S-WAY MANUFACTURING CO., INC.
#  1  (Exact name of registrant as specified in its ...
#
#                                                     1  \
#  0                  ART’S-WAY MANUFACTURING CO., INC.
#  1  (Exact name of registrant as specified in its ...
#
#                                                     2
#  0                  ART’S-WAY MANUFACTURING CO., INC.
#  1  (Exact name of registrant as specified in its ...  ,
#                                                     0   1  \
#  0                                           Delaware NaN
#  1  (State or other jurisdiction of  incorporation... NaN
#
#                                        2
# ...
